# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthdhulipalla/python-new/blob/module-4/module_04_part_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2,12,9,16,6,14,18])
y= np.array([4,18,5,18,2,10,8])

plt.plot(x, y)
plt.show()
plt.bar(x,y)
# Out:
# <BarContainer object of 7 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['chem','clad','it','c program','single','several','workshop','vdc'])
y= np.array([87,65,96,93,58,75,97,88])

plt.plot(x,y)
plt.show()
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([89,36,85,74])
marks = ["chem", "maths2", "evpr", "maths"]

plt.pie(y, labels = marks)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("math", fontdict = font1)
plt.xlabel("science", fontdict = font2)
plt.ylabel("social", fontdict = font2)

plt.plot(x, y)
plt.show()
